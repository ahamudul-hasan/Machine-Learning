# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../CSV/cars.csv")

df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df['name'].value_counts()
# Out:
# name
# Maruti Swift Dzire VDI                  69
# Maruti Alto 800 LXI                     59
# Maruti Alto LXi                         47
# Hyundai EON Era Plus                    35
# Maruti Alto LX                          35
#                                         ..
# Hyundai Santro AT                        1
# Hyundai Santro Xing XS eRLX Euro III     1
# Honda Amaze S Petrol BSIV                1
# Tata Indigo CS LS (TDI) BS-III           1
# Volkswagen CrossPolo 1.2 MPI             1
# Name: count, Length: 1491, dtype: int64

# %%
df['fuel'].value_counts()
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64

# %% [markdown]
# # One Hot Encoding

# %%
pd.get_dummies(df,columns=['fuel','owner'])
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#      seller_type transmission  fuel_CNG  fuel_Diesel  fuel_Electric  fuel_LPG  \
# 0     Individual       Manual     False        False          False     False
# 1     Individual       Manual     False        False          False     False
# 2     Individual       Manual     False         True          False     False
# 3     Individual       Manual     False        False          False     False
# 4     Individual       Manual     False         True          False     False
# ...          ...          ...       ...          ...            ...       ...
# 4335  Individual       Manual     False         True          False     False
# 4336  Individual       Manual     False         True          False     False
# 4337  Individual       Manual     False        False          False     False
# 4338  Individual       Manual     False         True          False     False
# 4339  Individual       Manual     False        False          False     False
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# 0            True               True                       False
# 1            True               True                       False
# 2           False               True                       False
# 3            True               True                       False
# 4           False              False                       False
# ...           ...                ...                         ...
# 4335        False              False                       False
# 4336        False              False                       False
# 4337         True              False                       False
# 4338        False               True                       False
# 4339         True               True                       False
#
#       owner_Second Owner  owner_Test Drive Car  owner_Third Owner
# 0                  False                 False              False
# 1                  False                 False              False
# 2                  False                 False              False
# 3                  False                 False              False
# 4                   True                 False              False
# ...                  ...                   ...                ...
# 4335                True                 False              False
# 4336                True                 False              False
# 4337                True                 False              False
# 4338               False                 False              False
# 4339               False                 False              False
#
# [4340 rows x 16 columns]

# %% [markdown]
# # One Hot Encoding (K-1)

# %%
pd.get_dummies(df,columns=['fuel','owner'],drop_first=True)
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#      seller_type transmission  fuel_Diesel  fuel_Electric  fuel_LPG  \
# 0     Individual       Manual        False          False     False
# 1     Individual       Manual        False          False     False
# 2     Individual       Manual         True          False     False
# 3     Individual       Manual        False          False     False
# 4     Individual       Manual         True          False     False
# ...          ...          ...          ...            ...       ...
# 4335  Individual       Manual         True          False     False
# 4336  Individual       Manual         True          False     False
# 4337  Individual       Manual        False          False     False
# 4338  Individual       Manual         True          False     False
# 4339  Individual       Manual        False          False     False
#
#       fuel_Petrol  owner_Fourth & Above Owner  owner_Second Owner  \
# 0            True                       False               False
# 1            True                       False               False
# 2           False                       False               False
# 3            True                       False               False
# 4           False                       False                True
# ...           ...                         ...                 ...
# 4335        False                       False                True
# 4336        False                       False                True
# 4337         True                       False                True
# 4338        False                       False               False
# 4339         True                       False               False
#
#       owner_Test Drive Car  owner_Third Owner
# 0                    False              False
# 1                    False              False
# 2                    False              False
# 3                    False              False
# 4                    False              False
# ...                    ...                ...
# 4335                 False              False
# 4336                 False              False
# 4337                 False              False
# 4338                 False              False
# 4339                 False              False
#
# [4340 rows x 14 columns]

# %% [markdown]
# # OHE using SKlearn

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 0     Petrol  Individual       Manual   First Owner
# 1     Petrol  Individual       Manual   First Owner
# 2     Diesel  Individual       Manual   First Owner
# 3     Petrol  Individual       Manual   First Owner
# 4     Diesel  Individual       Manual  Second Owner
# ...      ...         ...          ...           ...
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner
#
# [4340 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,:-1],df.iloc[:,-1],test_size=0.2,random_state=0)

# %%
X_train
# Out:
#                                               name  year  selling_price  \
# 159                  Chevrolet Enjoy 1.3 TCDi LS 8  2015         300000
# 4334  Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV  2012         600000
# 1657                     Maruti Esteem Vxi - BSIII  2006          95000
# 2188                           Honda City i VTEC V  2015         775000
# 581                       Chevrolet Beat LT Option  2016         239000
# ...                                            ...   ...            ...
# 1033                  Audi A6 2.0 TDI Premium Plus  2013        1300000
# 3264                      Chevrolet Beat Diesel LS  2012         120000
# 1653                               Datsun RediGO S  2016         270000
# 2607              Volkswagen Polo 1.5 TDI Highline  2015         600000
# 2732                      Maruti Wagon R VXI BS IV  2013         229999
#
#       km_driven    fuel       seller_type transmission
# 159      175000  Diesel        Individual       Manual
# 4334     170000  Diesel        Individual       Manual
# 1657     110000  Petrol        Individual       Manual
# 2188      66521  Petrol  Trustmark Dealer       Manual
# 581       41000  Petrol            Dealer       Manual
# ...         ...     ...               ...          ...
# 1033      58500  Diesel            Dealer    Automatic
# 3264     110000  Diesel        Individual       Manual
# 1653      22000  Petrol        Individual       Manual
# 2607      70000  Diesel        Individual       Manual
# 2732      62000  Petrol        Individual       Manual
#
# [3472 rows x 7 columns]

# %%
from sklearn.preprocessing import  OneHotEncoder 
ohe = OneHotEncoder(drop='first', sparse_output=False, dtype=np.int32)

# %%
X_train_encoded_temp = ohe.fit_transform(X_train[['fuel','owner']])
X_test_encoded_temp = ohe.transform(X_test[['fuel','owner']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 X_train_encoded_temp = ohe.fit_transform(X_train[['fuel','owner']])
#       2 X_test_encoded_temp = ohe.transform(X_test[['fuel','owner']])
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['owner'] not in index"

# %%
X_train_encoded_temp
